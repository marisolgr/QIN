# %% [markdown]
# ## Plot 2020, 2040 sSTa for marine heat waves

# %%
# import libraries
import numpy as np
import pandas as pd
#import geopandas as gpd
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import cartopy.feature as cfeature
import seaborn as sns
import warnings
warnings.simplefilter('ignore') # filter some warning messages

# %%
lpd =  '/Users/sol/Documents/LargeData/QIN/'

# %%
ds = xr.open_dataset('../Downscaleddata/spatial data for MHW and hypoxia frequency/surface_thetao_fre_245.nc')
ds.close()
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (decade: 11, lat: 97, lon: 132, model: 5)
# Coordinates:
#   * model    (model) object 'ACCESS-ESM1-5r1i1p1f1' ... 'UKESM1-0-LLr1i1p1f2'
#   * decade   (decade) int64 1990 2000 2010 2020 2030 ... 2060 2070 2080 2090
#   * lat      (lat) float32 41.0 41.083332 41.166668 ... 48.833332 48.916668 49.0
#   * lon      (lon) float32 229.0 229.08333 229.16667 ... 239.83334 239.91666
# Data variables:
#     thetao   (model, decade, lat, lon) float64 ...

# %%
ds.thetao[3,7,:,:].plot()

# %%
ds.model.values
# Out:
# array(['ACCESS-ESM1-5r1i1p1f1', 'CanESM5r1i1p1f1', 'GFDL-ESM4r1i1p1f1',
#        'IPSL-CM6A-LRr1i1p1f1', 'UKESM1-0-LLr1i1p1f2'], dtype=object)
