# %%
# map for quinault

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore') # filter some warning messages
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# %%
ldom = np.array([[42, 50],[-130, -122]])
qbox = np.array([[-124.05,-124.33,-125.07,-124.774,-124.05],[46.53,47.4,47.4,46.53,46.53]])
#qbox = np.array([[-124.5,-124,-124.3,-124.8,-124.5],[46.5,46.5,47.5,47.5,46.5]])

fecha=['1950-01-01','2019-12-31']

# %%
#get bathymetry from ETOPO1
fname_topo = '~/Documents/LargeData/Etopo/ETOPO1_Ice_g_gmt4.grd'
ds_topo = xr.open_dataset(fname_topo)
ds_topo.close()
topo = ds_topo.z  #(10801, 21601)
topo2=topo.sel(y=slice(ldom[0,0],ldom[0,1]),x=slice(ldom[1,0],ldom[1,1]))
x = topo2.x  #21601
y = topo2.y   #10801
X,Y=np.meshgrid(x,y)

# %%
fig=plt.figure(figsize=(5,4),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines(resolution='10m',linewidth=1.5,color='black',alpha=0.8,zorder=4)
ax.set_extent([ldom[1,0],ldom[1,1],ldom[0,0],ldom[0,1]],crs=ccrs.PlateCarree())
ax.set_xticks([*range(ldom[1,0],ldom[1,1]+1,5)], crs=ccrs.PlateCarree())
ax.set_yticks([*range(ldom[0,0],ldom[0,1]+1,5)], crs=ccrs.PlateCarree())
ax.xaxis.set_major_formatter(LongitudeFormatter(zero_direction_label=True))
ax.yaxis.set_major_formatter(LatitudeFormatter())
plt.grid(True, zorder=0,alpha=0.5)
#ax.set_aspect(1.5)
plt.contour(X,Y,topo2,[-5000,-2000,-1000,-500,-200,-100,-50],colors='k',linewidths=0.5, linestyles='solid', zorder=3, alpha=0.8)
#plt.contourf(sstm.longitude, sstm.latitude,sstm, levels=10,cmap='RdYlBu_r', zorder=2, alpha=0.7)
plt.plot(qbox[0,:],qbox[1,:],c='r',lw=2,zorder=5, alpha=0.7)
#plt.colorbar()
fig.savefig('./map_base.png')
plt.show()

# %%
ldom = np.array([[35, 55],[-135, -120]])
sdom = np.array([[46.5, 47.5],[-124.5, -124]])
fecha=['1950-01-01','2019-12-31']

# %%
#get bathymetry from ETOPO1
fname_topo = '~/Documents/LargeData/Etopo/ETOPO1_Ice_g_gmt4.grd'
ds_topo = xr.open_dataset(fname_topo)
ds_topo.close()
topo = ds_topo.z  #(10801, 21601)
topo2=topo.sel(y=slice(ldom[0,0],ldom[0,1]),x=slice(ldom[1,0],ldom[1,1]))
x = topo2.x  #21601
y = topo2.y   #10801
X,Y=np.meshgrid(x,y)

# %%
fig=plt.figure(figsize=(4,4),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines(resolution='10m',linewidth=1.5,color='black',alpha=0.8,zorder=4)
ax.set_extent([ldom[1,0],ldom[1,1],ldom[0,0],ldom[0,1]],crs=ccrs.PlateCarree())
ax.set_xticks([*range(ldom[1,0],ldom[1,1]+1,5)], crs=ccrs.PlateCarree())
ax.set_yticks([*range(ldom[0,0],ldom[0,1]+1,5)], crs=ccrs.PlateCarree())
ax.xaxis.set_major_formatter(LongitudeFormatter(zero_direction_label=True))
ax.yaxis.set_major_formatter(LatitudeFormatter())
plt.grid(True, zorder=0,alpha=0.5)
#ax.set_aspect(1.5)
plt.contour(X,Y,topo2,[-5000,-2000,-1000,-500,-200,-100,-50],colors='k',linewidths=0.5, linestyles='solid', zorder=3, alpha=0.8)
#plt.contourf(sstm.longitude, sstm.latitude,sstm, levels=10,cmap='RdYlBu_r', zorder=2, alpha=0.7)
plt.plot(qbox[0,:],qbox[1,:],c='r',lw=2,zorder=5, alpha=0.7)
#plt.colorbar()
fig.savefig('./map_base_large.png')
plt.show()

# %%
ldom = np.array([[45, 49],[-126, -123]])
qbox = np.array([[-124.5,-124,-124.3,-124.8,-124.5],[46.5,46.5,47.5,47.5,46.5]])
fecha=['1950-01-01','2019-12-31']

# %%
#get bathymetry from ETOPO1
fname_topo = '~/Documents/LargeData/Etopo/ETOPO1_Ice_g_gmt4.grd'
ds_topo = xr.open_dataset(fname_topo)
ds_topo.close()
topo = ds_topo.z  #(10801, 21601)
topo2=topo.sel(y=slice(ldom[0,0],ldom[0,1]),x=slice(ldom[1,0],ldom[1,1]))
x = topo2.x  #21601
y = topo2.y   #10801
X,Y=np.meshgrid(x,y)

# %%
fig=plt.figure(figsize=(4,4),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines(resolution='10m',linewidth=1.5,color='black',alpha=0.8,zorder=4)
ax.set_extent([ldom[1,0],ldom[1,1],ldom[0,0],ldom[0,1]],crs=ccrs.PlateCarree())
ax.set_xticks([*range(ldom[1,0],ldom[1,1]+1,3)], crs=ccrs.PlateCarree())
ax.set_yticks([*range(ldom[0,0],ldom[0,1]+1,3)], crs=ccrs.PlateCarree())
ax.xaxis.set_major_formatter(LongitudeFormatter(zero_direction_label=True))
ax.yaxis.set_major_formatter(LatitudeFormatter())
plt.grid(True, zorder=0,alpha=0.5)
#ax.set_aspect(1.5)
plt.contour(X,Y,topo2,[-2000,-1000,-500,-200,-150, -100,-75, -50,-25],colors='k',linewidths=0.5, linestyles='solid', zorder=3, alpha=0.8)
plt.plot(qbox[0,:],qbox[1,:],c='r',lw=2,zorder=5, alpha=0.7)
fig.savefig('./map_base_xsmall.png')
plt.show()

# %%
# more accurate map
# “Pacific Ocean waters between Point Chehalis (46°53.30' N Lat.) and 
# Destruction Island (47"40.1 0' N. Lat.), and 
# west to 30 nautical miles off shore.”
# @ 47.5 1 degree = 40.68nm  = 
# @ 46.5 1 degree = 41.45nm

qbox = np.array([[-124.05,-124.33,-125.07,-124.774,-124.05],[46.53,47.4,47.4,46.53,46.53]])

fig=plt.figure(figsize=(4,4),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines(resolution='10m',linewidth=1.5,color='black',alpha=0.8,zorder=4)
ax.set_extent([ldom[1,0],ldom[1,1],ldom[0,0],ldom[0,1]],crs=ccrs.PlateCarree())
ax.set_xticks([*range(ldom[1,0],ldom[1,1]+1,3)], crs=ccrs.PlateCarree())
ax.set_yticks([*range(ldom[0,0],ldom[0,1]+1,3)], crs=ccrs.PlateCarree())
ax.xaxis.set_major_formatter(LongitudeFormatter(zero_direction_label=True))
ax.yaxis.set_major_formatter(LatitudeFormatter())
plt.grid(True, zorder=0,alpha=0.5)
#ax.set_aspect(1.5)
plt.contour(X,Y,topo2,[-2000,-1000,-500,-200,-150, -100,-75, -50,-25],colors='k',linewidths=0.5, linestyles='solid', zorder=3, alpha=0.8)
plt.plot(qbox[0,:],qbox[1,:],c='r',lw=2,zorder=5, alpha=0.7)
fig.savefig('./map_base2_small_updated.png')
plt.show()

# %%
-124.05-0.724
# Out:
# -124.774
